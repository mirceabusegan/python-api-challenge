# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("generated_data/selected_cities.csv")

#Converting Kelvin to Celcius
def kelvin_to_celsius(temp_kelvin):
    return temp_kelvin - 273.15
city_data_df['Max Temp'] = city_data_df['Max Temp'].apply(kelvin_to_celsius)
    

# Display sample data
city_data_df.head()
# Out:
#    City_ID                    City      Lat       Lng  Max Temp  Humidity  \
# 0        0  zheleznogorsk-ilimskiy  56.5768  104.1217     15.70        71
# 1        1                 ushuaia -54.8000  -68.3000      4.81        81
# 2        2           haiku-pauwela  20.9219 -156.3051     27.92        77
# 3        3                weligama   5.9667   80.4167     27.73        91
# 4        4                holualoa  19.6228 -155.9522     26.59        92
#
#    Cloudiness  Wind Speed Country        Date
# 0         100        1.60      RU  1723924215
# 1          75        6.17      AR  1723923932
# 2          40        9.77      US  1723924215
# 3         100        4.51      LK  1723924215
# 4         100        2.57      US  1723924215

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map = city_data_df.hvplot.points(
    'Lng','Lat',
    geo = True,
    size = 'Humidity',
    scale = 1,
    color = 'City', 
    alpha = 0.5,
    tiles = 'OSM',
    frame_width = 800,
    frame_height = 400)

# Display the map
map
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values

narrowed_city_df = city_data_df.loc[
    (city_data_df['Max Temp']<37) & (city_data_df['Max Temp']>19) \
    & (city_data_df['Wind Speed'] < 4.5) \
    & (city_data_df ['Cloudiness'] == 0)]
# Drop any rows with null values
narrowed_city_df = narrowed_city_df.dropna()
# Display sample data
narrowed_city_df.head(5)
# Out:
#      City_ID         City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 67        67   zayed city  24.3768  54.5890     36.11        50           0
# 83        83      colonia  50.9333   6.9500     22.20        83           0
# 85        85       kourou   5.1552 -52.6478     28.91        64           0
# 104      104   constantia  44.1833  28.6500     21.50        65           0
# 105      105  nova vicosa -17.8919 -39.3719     23.57        66           0
#
#      Wind Speed Country        Date
# 67         4.12      AE  1723924217
# 83         1.54      DE  1723924217
# 85         4.05      GF  1723924217
# 104        2.99      RO  1723924217
# 105        4.01      BR  1723924217

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity

hotel_df = narrowed_city_df.loc[:,['City','Country','Lat','Lng','Humidity']]
# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name']=''

# Display sample data
hotel_df.head(10)
# Out:
#             City Country      Lat       Lng  Humidity Hotel Name
# 67    zayed city      AE  24.3768   54.5890        50
# 83       colonia      DE  50.9333    6.9500        83
# 85        kourou      GF   5.1552  -52.6478        64
# 104   constantia      RO  44.1833   28.6500        65
# 105  nova vicosa      BR -17.8919  -39.3719        66
# 111       pangoa      PE -12.1167  -73.0000        32
# 113        hotan      CN  37.0997   79.9269        17
# 149    dobroslav      UA  46.8194   30.9432        45
# 157   prabumulih      ID  -3.4500  104.2500        90
# 159         sona      IT  45.4388   10.8255        65

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    'categories':'accommodation.hotel',
    'apiKey':geoapify_key,
    'limit':20
    }

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    latitude = row['Lat']
    longitude = row['Lng']
    

    # Add the current city's latitude and longitude to the params dictionary
    params['filter'] = f'circle:{longitude},{latitude},{radius}'
    params['bias'] = f'proximity:{longitude},{latitude}'
  
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make and API request using the params dictionary
    name_address = requests.get(base_url, params=params)

    # Convert the API response to JSON format
    name_address = name_address.json()

    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"

    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df.head(6)
# Out:
# Starting hotel search
# zayed city - nearest hotel: L'Arabia hotel
# colonia - nearest hotel: Wasserturm Hotel Cologne
# kourou - nearest hotel: SCI Horizon
# constantia - nearest hotel: Hotel Dali
# nova vicosa - nearest hotel: Pousada Pontal da Barra
# pangoa - nearest hotel: No hotel found
# hotan - nearest hotel: Hua Yi International Hotel (accepts foreigners)
# dobroslav - nearest hotel: No hotel found
# prabumulih - nearest hotel: No hotel found
# sona - nearest hotel: Al Bosco
# suwayr - nearest hotel: No hotel found
# firminopolis - nearest hotel: hotel central
# pamandzi - nearest hotel: Gite Le Madina
# wuwei - nearest hotel: Hepingli Boutique Hotel
# lake los angeles - nearest hotel: No hotel found
# howard springs - nearest hotel: Rydges Palmerston
# gallup - nearest hotel: No hotel found
# galliano - nearest hotel: Fairfield Inn & Suites Cut Off-Galliano
# paros - nearest hotel: Hotel Acropolis
# jackson - nearest hotel: Brookside
# sharm el-sheikh - nearest hotel: Club El Faraana
# archangelos - nearest hotel: Semina
# extrema - nearest hotel: Hotel San Marco
# al kharijah - nearest hotel: Kharga Hotel
# katsuura - nearest hotel: 潮騒の宿
# berezanskaya - nearest hotel: No hotel found
# bukama - nearest hotel: Mission catholique
# saurimo - nearest hotel: Hotel Princesinha
# nova xavantina - nearest hotel: Hotel Morada do Sol
# abadan - nearest hotel: خانه معلم
# sefrou - nearest hotel: No hotel found
# princeville - nearest hotel: No hotel found
# port douglas - nearest hotel: Mantra Aqueous Port Douglas
# abha - nearest hotel: فندق المضياف
# oliver - nearest hotel: Coast Oliver Hotel
# newman - nearest hotel: No hotel found
# sevsk - nearest hotel: No hotel found
# al jawf - nearest hotel: No hotel found
# n'zeto - nearest hotel: Longe LUVUVAMO
# chadron - nearest hotel: Holiday Inn Express & Suites Chadron
# qingdao - nearest hotel: Le Méridien Qingdao
# mutuali - nearest hotel: No hotel found
# tabora - nearest hotel: Alpho hotel
#             City Country      Lat      Lng  Humidity                Hotel Name
# 67    zayed city      AE  24.3768  54.5890        50            L'Arabia hotel
# 83       colonia      DE  50.9333   6.9500        83  Wasserturm Hotel Cologne
# 85        kourou      GF   5.1552 -52.6478        64               SCI Horizon
# 104   constantia      RO  44.1833  28.6500        65                Hotel Dali
# 105  nova vicosa      BR -17.8919 -39.3719        66   Pousada Pontal da Barra
# 111       pangoa      PE -12.1167 -73.0000        32            No hotel found

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map = hotel_df.hvplot.points(
    'Lng',
    'Lat',
    geo = 'TRUE',
    size = 'Humidity',
    scale = 1,
    color = 'City',
    alpha = 0.5,
    tiles = 'OSM',
    frame_width = 800,
    frame_height = 400,
    hover_cols = ['Hotel Name', 'Country']
)
    
 

# Display the map
map
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
