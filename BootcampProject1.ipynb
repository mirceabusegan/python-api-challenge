# %% [markdown]
# <a href="https://colab.research.google.com/github/mirceabusegan/python-api-challenge/blob/main/BootcampProject1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
from pathlib import Path

# %%
# Save path to the data set as a variable.
data_file = Path("/content/sample_data/merged_filtered_data3.csv")
# Use Pandas to the read data.
data_file_df = pd.read_csv(data_file)
data_file_df.head()
# Out:
#    Is your primary role within your company related to tech/IT?  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#    Have you ever discussed your mental health with your employer?  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  1
# 4                                                  0
#
#   Would you feel comfortable discussing a mental health issue with your coworkers?  \
# 0                                              Maybe
# 1                                                Yes
# 2                                                 No
# 3                                              Maybe
# 4                                                 No
#
#    If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to clients or business contacts?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to coworkers or employees?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Do you *currently* have a mental health disorder?  \
# 0                                          Possibly
# 1                                        Don't Know
# 2                                          Possibly
# 3                                               Yes
# 4                                          Possibly
#
#   Have you ever been *diagnosed* with a mental health disorder?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                Yes
# 4                                                NaN
#
#    Anxiety Disorder (Generalized, Social, Phobia, etc)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Mood Disorder (Depression, Bipolar Disorder, etc)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Psychotic Disorder (Schizophrenia, Schizoaffective, etc)  ...  \
# 0                                                NaN         ...
# 1                                                NaN         ...
# 2                                                NaN         ...
# 3                                                NaN         ...
# 4                                                NaN         ...
#
#    Addictive Disorder  Other  \
# 0                 NaN    NaN
# 1                 NaN    NaN
# 2                 NaN    NaN
# 3                 NaN    NaN
# 4                 NaN    NaN
#
#    On a scale from 0 to 10, how willing would you be to share with friends and family that you have a mental illness?  \
# 0                                                  3
# 1                                                  7
# 2                                                  0
# 3                                                  9
# 4                                                  7
#
#    Would you bring up your *mental* health with a potential employer in an interview?  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#    What is your age?  What is your gender?  What country do you *live* in?  \
# 0                 26                  male        United States of America
# 1                 32                  Male                           India
# 2                 34                  Male        United States of America
# 3                 44                female        United States of America
# 4                 33                     M                           India
#
#            What is your race?  What country do you *work* in?  \
# 0                       White        United States of America
# 1                         NaN                           India
# 2  More than one of the above        United States of America
# 3                       White        United States of America
# 4                         NaN                           India
#
#    Submit Date (UTC)
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#
# [5 rows x 28 columns]

# %%
import matplotlib.pyplot as plt
import scipy.stats as st

# Build bar graph
# YOUR CODE HERE
filtered_df = data_file_df[["Have you ever discussed your mental health with your employer?", "What country do you *live* in?"]]
filtered_df.plot(kind='bar', stacked=True, figsize = (10,5))

# Incorporate the other graph properties
# YOUR CODE HERE
plt.xlabel("Country")
plt.ylabel("Have you ever discussed your mental health with your employer?")
plt.title("Mental Health discussion vs country of residence")

# Save the figure
"output_data/Fig1.png"

# Show plot
plt.show()

# %%
#code used to merge the four csvs



import pandas as pd

# Assuming the files are CSV, replace 'file1.csv', 'file2.csv', etc., with your actual file paths.
files = ['/content/OSMI 2020 Mental Health in Tech Survey Results .csv', '/content/OSMI 2021 Mental Health in Tech Survey Results .csv', '/content/responses.csv', '/content/responses_2021.csv']

# Define the columns you want to keep
columns_to_keep = [
    #'Are you self-employed?',
    'Is your primary role within your company related to tech/IT?',
    'Have you ever discussed your mental health with your employer?',
    'Would you feel comfortable discussing a mental health issue with your coworkers?',
    'If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to clients or business contacts?',
    'If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to coworkers or employees?',
    'Do you *currently* have a mental health disorder?',
    'Have you ever been *diagnosed* with a mental health disorder?',
    'Anxiety Disorder (Generalized, Social, Phobia, etc)',
    'Mood Disorder (Depression, Bipolar Disorder, etc)',
    'Psychotic Disorder (Schizophrenia, Schizoaffective, etc)',
    'Eating Disorder (Anorexia, Bulimia, etc)',
    'Attention Deficit Hyperactivity Disorder',
    'Personality Disorder (Borderline, Antisocial, Paranoid, etc)',
    'Obsessive-Compulsive Disorder',
    'Post-Traumatic Stress Disorder',
    'Stress Response Syndromes',
    'Dissociative Disorder',
    'Substance Use Disorder',
    'Addictive Disorder',
    'Other',
    'How willing would you be to share with friends and family that you have a mental illness?',
    'Would you bring up your *mental* health with a potential employer in an interview?',
    'What is your age?',
    'What is your gender?',
    'What country do you *live* in?',
    'What is your race?',
    'What country do you *work* in?',
    "Submit Date (UTC)"
]

# Read and merge the files
merged_df = pd.concat((pd.read_csv(file) for file in files), ignore_index=True)

# Keep only the specified columns
filtered_df = merged_df[columns_to_keep]
filtered_df=filtered_df.dropna(how='all')
filtered_df = filtered_df[filtered_df['Is your primary role within your company related to tech/IT?'] == 1]

# Save the merged and filtered DataFrame to a new file, if needed
filtered_df.to_csv('merged_filtered_data3.csv', index=False)

# Display the result (optional)
print(filtered_df.head())

files = ['/content/OSMI 2020 Mental Health in Tech Survey Results .csv', '/content/OSMI 2021 Mental Health in Tech Survey Results .csv', '/content/responses.csv', '/content/responses_2021.csv']

#graph thoughts
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-46-b4b60d387ee1> in <cell line: 44>()
#      42
#      43 # Read and merge the files
# ---> 44 merged_df = pd.concat((pd.read_csv(file) for file in files), ignore_index=True)
#      45
#      46 # Keep only the specified columns
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     378         copy = False
#     379
# --> 380     op = _Concatenator(
#     381         objs,
#     382         axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     441         self.copy = copy
#     442
# --> 443         objs, keys = self._clean_keys_and_objs(objs, keys)
#     444
#     445         # figure out what our result ndim is going to be
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/concat.py in _clean_keys_and_objs(self, objs, keys)
#     500             objs_list = [objs[k] for k in keys]
#     501         else:
# --> 502             objs_list = list(objs)
#     503
#     504         if len(objs_list) == 0:
#
# <ipython-input-46-b4b60d387ee1> in <genexpr>(.0)
#      42
#      43 # Read and merge the files
# ---> 44 merged_df = pd.concat((pd.read_csv(file) for file in files), ignore_index=True)
#      45
#      46 # Keep only the specified columns
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     946     kwds.update(kwds_defaults)
#     947
# --> 948     return _read(filepath_or_buffer, kwds)
#     949
#     950
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     609
#     610     # Create the parser.
# --> 611     parser = TextFileReader(filepath_or_buffer, **kwds)
#     612
#     613     if chunksize or iterator:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1446
#    1447         self.handles: IOHandles | None = None
# -> 1448         self._engine = self._make_engine(f, self.engine)
#    1449
#    1450     def close(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1703                 if "b" not in mode:
#    1704                     mode += "b"
# -> 1705             self.handles = get_handle(
#    1706                 f,
#    1707                 mode,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     861         if ioargs.encoding and "b" not in ioargs.mode:
#     862             # Encoding
# --> 863             handle = open(
#     864                 handle,
#     865                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/OSMI 2020 Mental Health in Tech Survey Results .csv'

# %%
#graph thoughts
# for every country in the survey and remote vs in person as a bar graph for two statistics like "are you willing to use recouses and how likely are you to tell various people"
#scattar / regression for some statistics ove time (submit date)

# %%
#Mircea
#here I created a loop for all the questions that have 10 or less types of answer
#I will plot a pie chart related to each question

questions_to_chart = [2,5,20,21]
for curent_question in questions_to_chart:
  question = data_file_df.iloc[:, curent_question]
  response_counts = question.value_counts()
  column_name = data_file_df.columns
  plt.figure(figsize=(6, 6))
  plt.pie(response_counts, labels=response_counts.index, autopct='%1.1f%%', startangle=140)
  plt.title(column_name[curent_question])
  plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
  plt.show()
